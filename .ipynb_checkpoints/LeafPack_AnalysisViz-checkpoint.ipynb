# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

import duckdb

# %% [markdown]
# ## Mass Loss Data

# %%
mass_lost_df = pd.read_csv('masslost_new.csv')
mass_lost_df = mass_lost_df.drop(['Lab (T/W)','ln (Corr Prop Initial Dry Mass)'], axis=1)
mass_lost_df = mass_lost_df.rename({'Leaf Species':'Species', '# Days in Stream':'Days', 'Rebar #':'Replicate', 
                                    'Initial Dry Mass (g)':'Initial_Mass','Final Dry Mass (g)':'Final_Mass',
                                    'Proportion of Initial Dry Mass (Uncorrected)': 'Proportion',
                                    'Handling Correction Factor':'Correction_Factor',
                                    'Corrected Proportion Initial Dry Mass':'Corrected_Proportion'}, axis=1)
mass_lost_df
# Out:
#                Species  Days Treatment  Replicate  Initial_Mass  Final_Mass  \
# 0       American Beech     0      Fine        NaN           NaN         NaN
# 1       American Beech     0    Coarse        NaN           NaN         NaN
# 2   Eastern Cottonwood     0      Fine        NaN           NaN         NaN
# 3   Eastern Cottonwood     0    Coarse        NaN           NaN         NaN
# 4       American Beech    42      Fine        2.0          2.99        1.99
# 5       American Beech    14    Coarse        1.0          3.00        2.45
# 6       American Beech    14    Coarse        2.0          3.01        2.22
# 7       American Beech    14    Coarse        3.0          2.97        2.10
# 8       American Beech    28    Coarse        1.0          3.01        1.87
# 9       American Beech    28    Coarse        2.0          2.92        1.98
# 10      American Beech    28    Coarse        3.0          2.96        2.01
# 11      American Beech    42    Coarse        1.0          2.99        1.91
# 12      American Beech    42    Coarse        2.0          2.97        2.11
# 13      American Beech    42    Coarse        3.0          2.99        1.77
# 14  Eastern Cottonwood    14      Fine        1.0          3.09        2.22
# 15  Eastern Cottonwood    14      Fine        2.0          3.04        2.09
# 16  Eastern Cottonwood    28      Fine        1.0          3.01        2.27
# 17  Eastern Cottonwood    42      Fine        1.0          2.97        1.71
# 18  Eastern Cottonwood    42      Fine        2.0          3.06        2.17
# 19  Eastern Cottonwood    14    Coarse        1.0          3.00        2.13
# 20  Eastern Cottonwood    14    Coarse        2.0          3.07        2.18
# 21  Eastern Cottonwood    14    Coarse        3.0          2.99        2.30
# 22  Eastern Cottonwood    28    Coarse        1.0          3.05        1.73
# 23  Eastern Cottonwood    28    Coarse        2.0          2.95        1.88
# 24  Eastern Cottonwood    28    Coarse        3.0          3.05        1.80
# 25  Eastern Cottonwood    42    Coarse        1.0          3.08        1.49
# 26  Eastern Cottonwood    42    Coarse        2.0          3.07        1.77
# 27  Eastern Cottonwood    42    Coarse        3.0          3.05        2.30
#
#     Proportion  Correction_Factor  Corrected_Proportion
# 0          NaN                NaN              1.000000
# 1          NaN                NaN              1.000000
# 2          NaN                NaN              1.000000
# 3          NaN                NaN              1.000000
# 4     0.665552           1.000000              0.665552
# 5     0.816667           1.203257              0.982660
# 6     0.737542           1.203257              0.887452
# 7     0.707071           1.203257              0.850788
# 8     0.621262           1.203257              0.747539
# 9     0.678082           1.203257              0.815907
# 10    0.679054           1.203257              0.817077
# 11    0.638796           1.203257              0.768636
# 12    0.710438           1.203257              0.854839
# 13    0.591973           1.203257              0.712296
# 14    0.718447           1.000000              0.718447
# 15    0.687500           1.000000              0.687500
# 16    0.754153           1.000000              0.754153
# 17    0.575758           1.000000              0.575758
# 18    0.709150           1.000000              0.709150
# 19    0.710000           1.133670              0.804906
# 20    0.710098           1.133670              0.805017
# 21    0.769231           1.133670              0.872054
# 22    0.567213           1.133670              0.643033
# 23    0.637288           1.133670              0.722475
# 24    0.590164           1.133670              0.669051
# 25    0.483766           1.133670              0.548432
# 26    0.576547           1.133670              0.653615
# 27    0.754098           1.133670              0.854899

# %%
mass_lost_df['ln_Corrected_Proportion'] = np.log(mass_lost_df['Corrected_Proportion'])
mass_lost_df
# Out:
#                Species  Days Treatment  Replicate  Initial_Mass  Final_Mass  \
# 0       American Beech     0      Fine        NaN           NaN         NaN
# 1       American Beech     0    Coarse        NaN           NaN         NaN
# 2   Eastern Cottonwood     0      Fine        NaN           NaN         NaN
# 3   Eastern Cottonwood     0    Coarse        NaN           NaN         NaN
# 4       American Beech    42      Fine        2.0          2.99        1.99
# 5       American Beech    14    Coarse        1.0          3.00        2.45
# 6       American Beech    14    Coarse        2.0          3.01        2.22
# 7       American Beech    14    Coarse        3.0          2.97        2.10
# 8       American Beech    28    Coarse        1.0          3.01        1.87
# 9       American Beech    28    Coarse        2.0          2.92        1.98
# 10      American Beech    28    Coarse        3.0          2.96        2.01
# 11      American Beech    42    Coarse        1.0          2.99        1.91
# 12      American Beech    42    Coarse        2.0          2.97        2.11
# 13      American Beech    42    Coarse        3.0          2.99        1.77
# 14  Eastern Cottonwood    14      Fine        1.0          3.09        2.22
# 15  Eastern Cottonwood    14      Fine        2.0          3.04        2.09
# 16  Eastern Cottonwood    28      Fine        1.0          3.01        2.27
# 17  Eastern Cottonwood    42      Fine        1.0          2.97        1.71
# 18  Eastern Cottonwood    42      Fine        2.0          3.06        2.17
# 19  Eastern Cottonwood    14    Coarse        1.0          3.00        2.13
# 20  Eastern Cottonwood    14    Coarse        2.0          3.07        2.18
# 21  Eastern Cottonwood    14    Coarse        3.0          2.99        2.30
# 22  Eastern Cottonwood    28    Coarse        1.0          3.05        1.73
# 23  Eastern Cottonwood    28    Coarse        2.0          2.95        1.88
# 24  Eastern Cottonwood    28    Coarse        3.0          3.05        1.80
# 25  Eastern Cottonwood    42    Coarse        1.0          3.08        1.49
# 26  Eastern Cottonwood    42    Coarse        2.0          3.07        1.77
# 27  Eastern Cottonwood    42    Coarse        3.0          3.05        2.30
#
#     Proportion  Correction_Factor  Corrected_Proportion  \
# 0          NaN                NaN              1.000000
# 1          NaN                NaN              1.000000
# 2          NaN                NaN              1.000000
# 3          NaN                NaN              1.000000
# 4     0.665552           1.000000              0.665552
# 5     0.816667           1.203257              0.982660
# 6     0.737542           1.203257              0.887452
# 7     0.707071           1.203257              0.850788
# 8     0.621262           1.203257              0.747539
# 9     0.678082           1.203257              0.815907
# 10    0.679054           1.203257              0.817077
# 11    0.638796           1.203257              0.768636
# 12    0.710438           1.203257              0.854839
# 13    0.591973           1.203257              0.712296
# 14    0.718447           1.000000              0.718447
# 15    0.687500           1.000000              0.687500
# 16    0.754153           1.000000              0.754153
# 17    0.575758           1.000000              0.575758
# 18    0.709150           1.000000              0.709150
# 19    0.710000           1.133670              0.804906
# 20    0.710098           1.133670              0.805017
# 21    0.769231           1.133670              0.872054
# 22    0.567213           1.133670              0.643033
# 23    0.637288           1.133670              0.722475
# 24    0.590164           1.133670              0.669051
# 25    0.483766           1.133670              0.548432
# 26    0.576547           1.133670              0.653615
# 27    0.754098           1.133670              0.854899
#
#     ln_Corrected_Proportion
# 0                  0.000000
# 1                  0.000000
# 2                  0.000000
# 3                  0.000000
# 4                 -0.407139
# 5                 -0.017492
# 6                 -0.119400
# 7                 -0.161592
# 8                 -0.290969
# 9                 -0.203454
# 10                -0.202022
# 11                -0.263138
# 12                -0.156842
# 13                -0.339261
# 14                -0.330664
# 15                -0.374693
# 16                -0.282160
# 17                -0.552069
# 18                -0.343688
# 19                -0.217030
# 20                -0.216892
# 21                -0.136904
# 22                -0.441560
# 23                -0.325073
# 24                -0.401894
# 25                -0.600693
# 26                -0.425237
# 27                -0.156772

# %%
sns.set_theme()

# %%
ax = sns.lineplot(data=mass_lost_df, 
                  x='Days', y='Corrected_Proportion', 
                  hue='Treatment', hue_order=('Coarse','Fine'), style='Species', palette='husl',
                  err_style="bars", errorbar=("se", 2), err_kws=dict(fmt='o', markersize=8, capsize=5))

ax.set(title='Change of Proportion of Initial Mass Through Days in Stream\n(Handling Corrected)',
       xlabel='Days in Stream', ylabel='Proportion of Dry Mass Relative to Initial Mass\n(Handling Corrected)', 
       xticks=[0,14,28,42])
plt.show;

# %%
ax = sns.lineplot(data=mass_lost_df, 
                  x='Days', y='Corrected_Proportion', 
                  hue='Treatment', hue_order=('Coarse','Fine'), style='Species', palette='husl',
                  err_style="bars", errorbar=("se", 2), err_kws=dict(fmt='o', markersize=8, capsize=5))

ax.set(title='Change of Proportion of Initial Mass Through Days in Stream\n(Logarithmic Scale, Handling Corrected)',
       xlabel='Days in Stream', ylabel='Proportion of Dry Mass Relative to Initial Mass\n(Handling Corrected)',
       yscale='log', xticks=[0,14,28,42])
plt.show;

# %%
summarized_df = duckdb.sql("""SELECT Species, Days, Treatment, 
                                    AVG(Corrected_Proportion) AS AVG_Corrected_Proportion, 
                                    AVG(ln_Corrected_Proportion) AS AVG_ln_Corrected_Proportion,
                                    2*STDDEV(Corrected_Proportion)/SQRT(COUNT(Corrected_Proportion)) AS Double_Std_Err, 
                                    2*STDDEV(ln_Corrected_Proportion)/SQRT(COUNT(ln_Corrected_Proportion)) AS Double_ln_Std_Err
                                FROM mass_lost_df
                                GROUP BY Species, Days, Treatment""").df()
summarized_df
# Out:
#                Species  Days Treatment  AVG_Corrected_Proportion  \
# 0       American Beech     0      Fine                  1.000000
# 1       American Beech     0    Coarse                  1.000000
# 2   Eastern Cottonwood     0      Fine                  1.000000
# 3   Eastern Cottonwood     0    Coarse                  1.000000
# 4       American Beech    42      Fine                  0.665552
# 5       American Beech    14    Coarse                  0.906967
# 6       American Beech    28    Coarse                  0.793508
# 7       American Beech    42    Coarse                  0.778591
# 8   Eastern Cottonwood    14      Fine                  0.702973
# 9   Eastern Cottonwood    28      Fine                  0.754153
# 10  Eastern Cottonwood    42      Fine                  0.642454
# 11  Eastern Cottonwood    14    Coarse                  0.827326
# 12  Eastern Cottonwood    28    Coarse                  0.678186
# 13  Eastern Cottonwood    42    Coarse                  0.685648
#
#     AVG_ln_Corrected_Proportion  Double_Std_Err  Double_ln_Std_Err
# 0                      0.000000             NaN                NaN
# 1                      0.000000             NaN                NaN
# 2                      0.000000             NaN                NaN
# 3                      0.000000             NaN                NaN
# 4                     -0.407139             NaN                NaN
# 5                     -0.099495        0.078598           0.085545
# 6                     -0.232149        0.045974           0.058826
# 7                     -0.253080        0.082897           0.105799
# 8                     -0.352679        0.030947           0.044030
# 9                     -0.282160             NaN                NaN
# 10                    -0.447878        0.133393           0.208381
# 11                    -0.190275        0.044729           0.053372
# 12                    -0.389509        0.046767           0.068385
# 13                    -0.394234        0.179816           0.258166

# %%
# Calculate regression coefficients for the first dataset
data1 = summarized_df[(summarized_df['Species']=='Eastern Cottonwood') & (summarized_df['Treatment']=='Coarse')]
m1, b1 = np.polyfit(data1['Days'], data1['AVG_ln_Corrected_Proportion'], 1)

# Calculate regression coefficients for the second dataset
data2 = summarized_df[(summarized_df['Species']=='Eastern Cottonwood') & (summarized_df['Treatment']=='Fine')]
m2, b2 = np.polyfit(data2['Days'], data2['AVG_ln_Corrected_Proportion'], 1)


ax = sns.regplot(data=summarized_df[(summarized_df['Species']=='Eastern Cottonwood') & (summarized_df['Treatment']=='Coarse')], 
                  x='Days', y='AVG_ln_Corrected_Proportion', color='black', ci=None, label='Coarse')
ax = sns.regplot(data=summarized_df[(summarized_df['Species']=='Eastern Cottonwood') & (summarized_df['Treatment']=='Fine')], 
                  x='Days', y='AVG_ln_Corrected_Proportion', color='red', ci=None, label='Fine')

plt.errorbar(data1['Days'], data1['AVG_ln_Corrected_Proportion'], yerr=data1['Double_Std_Err'], fmt='o', color='black', capsize=5)
plt.errorbar(data2['Days'], data2['AVG_ln_Corrected_Proportion'], yerr=data2['Double_Std_Err'], fmt='o', color='red', capsize=5)


ax.set(title='Proportion of Initial Mass Through Days in Stream\nfor Eastern Cottonwood (Handling Corrected)',
       xlabel='Days in Stream', ylabel='Proportion of Dry Mass Relative to Initial Mass\n(Handling Corrected, Logarithmic Scale)',
       xticks=[0,14,28,42]
      )
ax.legend()

ax.text(s=f"y = {m1:.5f}x + {b1:.2f}", color="black", x=45, y=0.0)
ax.text(s=f"y = {m2:.5f}x + {b2:.2f}", color="red", x=45, y=-0.05)

plt.show;

# %%
# Calculate regression coefficients for the first dataset
data1 = summarized_df[(summarized_df['Species']=='American Beech') & (summarized_df['Treatment']=='Coarse')]
m1, b1 = np.polyfit(data1['Days'], data1['AVG_ln_Corrected_Proportion'], 1)

# Calculate regression coefficients for the second dataset
data2 = summarized_df[(summarized_df['Species']=='American Beech') & (summarized_df['Treatment']=='Fine')]
m2, b2 = np.polyfit(data2['Days'], data2['AVG_ln_Corrected_Proportion'], 1)


ax = sns.regplot(data=summarized_df[(summarized_df['Species']=='American Beech') & (summarized_df['Treatment']=='Coarse')], 
                  x='Days', y='AVG_ln_Corrected_Proportion', color='black', ci=None, label='Coarse')
ax = sns.regplot(data=summarized_df[(summarized_df['Species']=='American Beech') & (summarized_df['Treatment']=='Fine')], 
                  x='Days', y='AVG_ln_Corrected_Proportion', color='red', ci=None, label='Fine')

plt.errorbar(data1['Days'], data1['AVG_ln_Corrected_Proportion'], yerr=data1['Double_Std_Err'], fmt='o', color='black', capsize=5)
plt.errorbar(data2['Days'], data2['AVG_ln_Corrected_Proportion'], yerr=data2['Double_Std_Err'], fmt='o', color='red', capsize=5)


ax.set(title='Proportion of Initial Mass Through Days in Stream\nfor American Beech (Handling Corrected)',
       xlabel='Days in Stream', ylabel='Proportion of Dry Mass Relative to Initial Mass\n(Handling Corrected, Logarithmic Scale)',
       xticks=[0,14,28,42]
      )
ax.legend()

ax.text(s=f"y = {m1:.5f}x + {b1:.2f}", color="black", x=45, y=-0.01)
ax.text(s=f"y = {m2:.5f}x + {b2:.2f}", color="red", x=45, y=-0.04)

plt.show;

# %% [markdown]
# ## Invertebrate Data

# %%
invert_df = pd.read_csv('invert.csv')
invert_df['Days'] = invert_df['Week'] * 7
invert_df = invert_df.drop(['Group','Lab', 'Week'], axis=1)
invert_df
# Out:
#                Species Treatment  Replicate          Order          Family  \
# 0       american beech         C          1        Diptera       Tipulidae
# 1       american beech         C          1  Ephemeroptera        Baetidae
# 2       american beech         C          1  Ephemeroptera  Ephemerellidae
# 3       american beech         C          1    Trichoptera  Hydropsychidae
# 4       american beech         C          2  Ephemeroptera   Heptageniidae
# ..                 ...       ...        ...            ...             ...
# 82  eastern cottonwood         F          1    Trichoptera  Hydropsychidae
# 83  eastern cottonwood         F          2        Diptera    Chironomidae
# 84  eastern cottonwood         F          2  Ephemeroptera   Heptageniidae
# 85  eastern cottonwood         F          2     Plecoptera  Chloroperlidae
# 86  eastern cottonwood         F          2    Trichoptera  Hydropsychidae
#
#               Genus              FFG  Count  Days
# 0           Antocha               CG      5    14
# 1            Baetis               CG      1    14
# 2          Drunella               SC      2    14
# 3       Hydropsyche               CF      4    14
# 4         Stenacron               SC      1    14
# ..              ...              ...    ...   ...
# 82      Hydropsyche               CF      6    42
# 83  (no need to ID)  Many CG, Some P      2    42
# 84        Stenacron               SC      7    42
# 85       Haploperla                P      3    42
# 86      Hydropsyche               CF      1    42
#
# [87 rows x 9 columns]

# %%
invert_df['FFG'].unique()
# Out:
# array(['CG', 'SC', 'CF', 'Many CG, Some P', 'P', 'SH'], dtype=object)

# %%
def FFG_reclass(original):
    if original == 'Many CG, Some P':
        return 'P'
    else:
        return original
invert_df['FFG']=invert_df['FFG'].apply(FFG_reclass)
invert_df
# Out:
#                Species Treatment  Replicate          Order          Family  \
# 0       american beech         C          1        Diptera       Tipulidae
# 1       american beech         C          1  Ephemeroptera        Baetidae
# 2       american beech         C          1  Ephemeroptera  Ephemerellidae
# 3       american beech         C          1    Trichoptera  Hydropsychidae
# 4       american beech         C          2  Ephemeroptera   Heptageniidae
# ..                 ...       ...        ...            ...             ...
# 82  eastern cottonwood         F          1    Trichoptera  Hydropsychidae
# 83  eastern cottonwood         F          2        Diptera    Chironomidae
# 84  eastern cottonwood         F          2  Ephemeroptera   Heptageniidae
# 85  eastern cottonwood         F          2     Plecoptera  Chloroperlidae
# 86  eastern cottonwood         F          2    Trichoptera  Hydropsychidae
#
#               Genus FFG  Count  Days
# 0           Antocha  CG      5    14
# 1            Baetis  CG      1    14
# 2          Drunella  SC      2    14
# 3       Hydropsyche  CF      4    14
# 4         Stenacron  SC      1    14
# ..              ...  ..    ...   ...
# 82      Hydropsyche  CF      6    42
# 83  (no need to ID)   P      2    42
# 84        Stenacron  SC      7    42
# 85       Haploperla   P      3    42
# 86      Hydropsyche  CF      1    42
#
# [87 rows x 9 columns]

# %%
data = invert_df[invert_df['Treatment']=='C']

# Create a pivot table for the data
pivot_data = data.pivot_table(index='Days', columns='FFG', values='Count', aggfunc='sum', fill_value=0)

# Plotting
ax = pivot_data.plot(kind='bar', stacked=True)

# Set titles and labels
ax.set_title('Change in Abundance of Invertebrates through Days in Stream\nClassified According to Functional Feeding Groups')
ax.set_xlabel('Days in Stream')
ax.set_ylabel('Count of Invertebrates')
ax.legend(title='Functional Feeding Groups')

plt.show()

# %%
"""
ax = sns.barplot(data=invert_df[invert_df['Treatment']=='F'], 
                 x='Days', y='Count', hue='FFG', 
                 palette='deep', 
                 estimator='sum', errorbar=None
                )
ax.legend(title='Functional Feeding Groups')
ax.set(title='Change in Abundance of Invertebrates through Days in Stream\nClassified According to Functional Feeding Groups',
       xlabel='Days in Stream', ylabel='Count of Invertebrates')
plt.show()
"""
# Out:
# "\nax = sns.barplot(data=invert_df[invert_df['Treatment']=='F'], \n                 x='Days', y='Count', hue='FFG', \n                 palette='deep', \n                 estimator='sum', errorbar=None\n                )\nax.legend(title='Functional Feeding Groups')\nax.set(title='Change in Abundance of Invertebrates through Days in Stream\nClassified According to Functional Feeding Groups',\n       xlabel='Days in Stream', ylabel='Count of Invertebrates')\nplt.show()\n"

# %%
ax = sns.barplot(data=invert_df[invert_df['Treatment']=='C'], 
                 x='Days', y='Count', hue='Species', 
                 palette='deep', 
                 estimator='sum', errorbar=None
                )
ax.legend(title='Leaf Species')
ax.set(title='Change in Abundance of Invertebrates through Days in Stream\nby Species of Leaf',
       xlabel='Days in Stream', ylabel='Count of Invertebrates')
plt.show()

# %%
ax = sns.barplot(data=invert_df, 
                 x='Days', y='Count', hue='Treatment', 
                 palette='husl', 
                 estimator='sum', errorbar=None
                )
ax.legend(title='Treatment')
ax.set(title='Change in Abundance of Invertebrates through Days in Stream\nby Treatment',
       xlabel='Days in Stream', ylabel='Count of Invertebrates')
plt.show()

# %%
# To ensure that all days are represented, we need to verify the data and potentially set the order of 'Days'
day_order = sorted(invert_df['Days'].unique())

# Recreating the facet grid with specified day order
g = sns.FacetGrid(data=invert_df, col='Species', row='Treatment', height=3, aspect=1.5)
g.map_dataframe(sns.barplot, x='Days', y='Count', hue='FFG', palette='deep', estimator=np.sum, hue_order=hue_order, order=day_order, errorbar=None)

# Adjusting the layout and adding legend
g.tight_layout()
g.set_axis_labels("Days in Stream", "Count of Invertebrates")
g.add_legend(title='Functional\nFeeding\nGroups')
plt.suptitle("Abundance of Invertebrates Through Days in Stream by FFG", y=1.02)

# Displaying the plots
plt.show()

# %%
invert_genera_richness_df = duckdb.sql("""SELECT Species, Treatment, Days, COUNT(DISTINCT Genus) AS Genera_Richness
                                            FROM invert_df
                                            GROUP BY Species, Treatment, Days""").df()
invert_genera_richness_df
# Out:
#                Species Treatment  Days  Genera_Richness
# 0       american beech         C    14                5
# 1       american beech         F    14                2
# 2       american beech         C    28                7
# 3       american beech         F    28                3
# 4       american beech         C    42                9
# 5       american beech         F    42                6
# 6   eastern cottonwood         C    14                4
# 7   eastern cottonwood         C    28                7
# 8   eastern cottonwood         F    28                2
# 9   eastern cottonwood         C    42               10
# 10  eastern cottonwood         F    42                4

# %%
g = sns.FacetGrid(data=invert_genera_richness_df, col='Species', height=3, aspect=1.5)
g.map_dataframe(sns.barplot, x='Days', y='Genera_Richness', hue='Treatment', palette='husl', errorbar=None)

g.tight_layout()
g.set_axis_labels("Days in Stream", "Generic Richness of Invertebrates")
g.add_legend(title='Treatment')
plt.suptitle("Generic Richness of Invertebrates Through Days in Stream by Treatment", y=1.02)
# Out:
# Text(0.5, 1.02, 'Generic Richness of Invertebrates Through Days in Stream by Treatment')

# %%
# Step 1: Filter out families with a total count less than 5
filtered_df = invert_df.groupby('Family').filter(lambda x: x['Count'].sum() >= 5)

# Step 2: Order by sum of 'Count' within each 'Family'
# This creates a new DataFrame with the sum of counts for each family
sum_counts = filtered_df.groupby('Family')['Count'].sum().reset_index()

# Sorting the families based on sum of counts in descending order
sorted_families = sum_counts.sort_values('Count', ascending=False)['Family']

# Step 3: Create the barplot
# Using the 'order' parameter to order the bars

g = sns.FacetGrid(data=filtered_df, row='Treatment', col='Species', height=3.5, aspect=1.5)
g.map_dataframe(sns.barplot, data=filtered_df, x='Count', y='Family', 
            orient='h', 
            hue=filtered_df['Days'].astype(str), 
            palette='mako', 
            estimator=np.sum, 
            errorbar=None,
            order=sorted_families)

g.set_axis_labels("Count of Invertebrates", "Family")
plt.suptitle("Abundance of Invertebrates Through Days in Stream by Family", y=1.02)
g.add_legend(title='Days\nin Stream')

# %%
invert_summary_df = duckdb.sql("""SELECT Species, Treatment, 
                                                AVG(COUNT) AS Avg, 
                                                STDDEV(COUNT)/SQRT(COUNT(COUNT)) AS Std_Err
                                            FROM invert_df
                                            GROUP BY Species, Treatment""").df()
invert_summary_df
# Out:
#               Species Treatment       Avg   Std_Err
# 0      american beech         C  3.944444  0.722588
# 1      american beech         F  4.380952  1.319228
# 2  eastern cottonwood         C  2.173913  0.278705
# 3  eastern cottonwood         F  5.428571  1.784285

# %%
def FFG_coll_reclass(original):
    if (original == 'CG') or (original == 'CF'):
        return 'C'
    else:
        return original

invert_reclass_df = invert_df.copy()
invert_reclass_df['FFG'] = invert_df['FFG'].apply(FFG_coll_reclass)
invert_reclass_df
# Out:
#                Species Treatment  Replicate          Order          Family  \
# 0       american beech         C          1        Diptera       Tipulidae
# 1       american beech         C          1  Ephemeroptera        Baetidae
# 2       american beech         C          1  Ephemeroptera  Ephemerellidae
# 3       american beech         C          1    Trichoptera  Hydropsychidae
# 4       american beech         C          2  Ephemeroptera   Heptageniidae
# ..                 ...       ...        ...            ...             ...
# 82  eastern cottonwood         F          1    Trichoptera  Hydropsychidae
# 83  eastern cottonwood         F          2        Diptera    Chironomidae
# 84  eastern cottonwood         F          2  Ephemeroptera   Heptageniidae
# 85  eastern cottonwood         F          2     Plecoptera  Chloroperlidae
# 86  eastern cottonwood         F          2    Trichoptera  Hydropsychidae
#
#               Genus FFG  Count  Days
# 0           Antocha   C      5    14
# 1            Baetis   C      1    14
# 2          Drunella  SC      2    14
# 3       Hydropsyche   C      4    14
# 4         Stenacron  SC      1    14
# ..              ...  ..    ...   ...
# 82      Hydropsyche   C      6    42
# 83  (no need to ID)   P      2    42
# 84        Stenacron  SC      7    42
# 85       Haploperla   P      3    42
# 86      Hydropsyche   C      1    42
#
# [87 rows x 9 columns]

# %%
invert_FFG_summary_df = duckdb.sql("""SELECT Species, Treatment, FFG,
                                                AVG(COUNT) AS Avg, 
                                                STDDEV(COUNT)/SQRT(COUNT(COUNT)) AS Std_Err
                                            FROM invert_reclass_df
                                            GROUP BY Species, Treatment, FFG""").df()
invert_FFG_summary_df
# Out:
#                Species Treatment FFG       Avg   Std_Err
# 0       american beech         C   C  5.578947  1.231449
# 1       american beech         C  SC  1.625000  0.263052
# 2       american beech         F   C  1.888889  0.260579
# 3       american beech         C   P  3.000000  0.654654
# 4       american beech         C  SH  1.000000  0.000000
# 5       american beech         F  SH  3.000000  2.000000
# 6       american beech         F   P  8.375000  3.011511
# 7       american beech         F  SC  1.000000  0.000000
# 8   eastern cottonwood         C   C  2.000000  0.348155
# 9   eastern cottonwood         C  SC  1.500000  0.288675
# 10  eastern cottonwood         C  SH  2.800000  0.663325
# 11  eastern cottonwood         C   P  3.000000  2.000000
# 12  eastern cottonwood         F   P  6.666667  4.176655
# 13  eastern cottonwood         F   C  3.666667  1.452966
# 14  eastern cottonwood         F  SC  7.000000       NaN
